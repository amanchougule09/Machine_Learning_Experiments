# %% [markdown]
# # LINEAR REGRETION

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('stud.csv')

# %%
df
# Out:
#     Salary  Experience
# 0    11000         2.0
# 1    12000         3.0
# 2    13000         4.0
# 3    14000         5.0
# 4    15000         5.5
# 5    16000         6.0
# 6    18000         6.5
# 7    20000         7.0
# 8    21000         8.0
# 9    22000         8.5
# 10   24000         9.0
# 11   25000         9.2
# 12   26000         9.4
# 13   27000         9.8
# 14   30000        10.0
# 15   32000        10.4
# 16   34000        10.8
# 17   36000        11.0
# 18   38000        11.5

# %%
plt.scatter(df['Experience'],df['Salary'])
plt.ylabel('Salary')
plt.xlabel('Experience')
plt.ylim([10000,38000])
plt.xlim([1,12])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X = df[['Experience']]   
y = df['Salary']
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(988.7466356295881)

# %%
#data is like['col1','col2','col3','col4']

# %%
import numpy as np
import pandas as pd

X = np.random.randint(0, 9, (50, 3))
y=0.5* X [:,0]-1.5* X [:,1] + X [:,2]-2

df1 = pd.DataFrame(X, columns=['col1', 'col2', 'col3'])

df1['col4'] = y
df1.to_csv('customeradata.csv', index=False)

# %%
df1
# Out:
#     col1  col2  col3  col4
# 0      4     8     4  -8.0
# 1      0     2     4  -1.0
# 2      3     2     8   4.5
# 3      1     0     4   2.5
# 4      3     2     6   2.5
# 5      1     0     1  -0.5
# 6      2     4     3  -4.0
# 7      5     6     5  -3.5
# 8      2     1     8   5.5
# 9      4     0     8   8.0
# 10     1     2     2  -2.5
# 11     0     4     0  -8.0
# 12     4     3     3  -1.5
# 13     3     1     5   3.0
# 14     2     8     2 -11.0
# 15     1     1     1  -2.0
# 16     8     6     6  -1.0
# 17     5     2     5   2.5
# 18     1     4     4  -3.5
# 19     8     3     7   4.5
# 20     6     6     3  -5.0
# 21     5     0     3   3.5
# 22     3     5     7  -1.0
# 23     2     0     2   1.0
# 24     8     1     8   8.5
# 25     3     8     0 -12.5
# 26     1     7     7  -5.0
# 27     1     2     0  -4.5
# 28     4     1     7   5.5
# 29     6     5     8   1.5
# 30     5     5     0  -7.0
# 31     0     0     0  -2.0
# 32     0     4     1  -7.0
# ...

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(X,y)
# Out:
# LinearRegression()

# %%
model1.intercept_
# Out:
# np.float64(-1.9999999999999982)

# %%
model1.coef_
# Out:
# array([ 0.5, -1.5,  1. ])

# %%
q=[[1,1,1,]]

# %%
model1.predict(q)
# Out:
# array([-2.])

# %%
yp=model.predict(q)

# %%
yp
# Out:
# array([-2.])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Salary_Data_multi.csv')
df
# Out:
#     YearsExperience   Age  Salary
# 0               1.1  21.0   39343
# 1               1.3  21.5   46205
# 2               1.5  21.7   37731
# 3               2.0  22.0   43525
# 4               2.2  22.2   39891
# 5               2.9  23.0   56642
# 6               3.0  23.0   60150
# 7               3.2  23.3   54445
# 8               3.2  23.3   64445
# 9               3.7  23.6   57189
# 10              3.9  23.9   63218
# 11              4.0  24.0   55794
# 12              4.0  24.0   56957
# 13              4.1  24.0   57081
# 14              4.5  25.0   61111
# 15              4.9  25.0   67938
# 16              5.1  26.0   66029
# 17              5.3  27.0   83088
# 18              5.9  28.0   81363
# 19              6.0  29.0   93940
# 20              6.8  30.0   91738
# 21              7.1  30.0   98273
# 22              7.9  31.0  101302
# 23              8.2  32.0  113812
# 24              8.7  33.0  109431
# 25              9.0  34.0  105582
# ...

# %%
plt.scatter(df['YearsExperience'], df['Salary'])
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.ylim([38000,125000])
plt.xlim([1.1,11])
plt.show()

# %%
x = df[['YearsExperience', 'Age']]
y = df['Salary']

# %%
#split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((21, 2), (9, 2), (21,), (9,))

# %%
from sklearn.linear_model import LinearRegression 
Model=LinearRegression ()
Model.fit(x_train,y_train)
Model.score(x_test,y_test)
# Out:
# 0.9362189206355989
